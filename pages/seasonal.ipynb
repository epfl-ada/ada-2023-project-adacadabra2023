# %%
import os
import sys
import pickle as pkl

repo_path = '/root/ADA2023/ada-2023-project-adacadabra2023/ada-2023-project-adacadabra2023' # CHANGE
sys.path.append(repo_path)

from src.data.Data import load_data

# %%
dpath = os.path.join(repo_path, 'Data', 'Unified_ratings.pkl')
with open(dpath, 'rb') as f:
    df = pkl.load(f)
print(df.shape)
# Out:
# (10932248, 18)

# %% [markdown]
# # Columns filtration

# %%
df.columns
# Out:
# Index(['beer_name', 'beer_id', 'brewery_name', 'brewery_id', 'style', 'date',
#        'rating', 'user_id', 'Procedence', 'country_user', 'country_brewery',
#        'year', 'Season', 'z_score', 'exp_mean', 'diff_exp_mean', 'ith_rating',
#        'detrend'],
#       dtype='object')

# %%
filtered_df['style'].nunique()
# Out:
# 186

# %%
filtered_df = df[['style','Season', 'country_user']]

# %%
seasonal_groups = filtered_df.groupby(['Season','country_user'])['style'].value_counts().unstack()
season_df = seasonal_groups.fillna(0)

# %%
df_toappend = season_df[[]]

# %%
first_style = seasonal_groups.idxmax(axis = 1, numeric_only = True).to_frame()

# %%
first_style['0'] = ''
# Out:
#                                               0
# Season country_user
# Autumn Andorra                     Abbey Tripel
#        Antarctica                        Porter
#        Aotearoa                English Pale Ale
#        Argentina         American Adjunct Lager
#        Ascension Island              Pale Lager
# ...                                         ...
# Winter Uruguay                       Pale Lager
#        Uzbekistan                         Stout
#        Venezuela           India Pale Ale (IPA)
#        Vietnam           American Adjunct Lager
#        Wales                             Bitter
#
# [604 rows x 1 columns]

# %%
df_toappend = filtered_df.groupby(['Season','country_user']).value_counts().to_frame()
df_toappend
# Out:
#                                           0
# Season country_user style
# Autumn Andorra       Abbey Tripel         4
#                      Dunkel/Tmavý         3
#                      Abbey Dubbel         3
#                      German Hefeweizen    3
#                      Belgian Strong Ale   3
# ...                                      ..
# Winter Wales         Smoked               1
#                      Specialty Grain      1
#                      Weizen Bock          1
#                      Altbier              1
#                      American Strong Ale  1
#
# [70304 rows x 1 columns]

# %%
seasonal_groups
# Out:
# style                     Abbey Dubbel   Abbey Tripel   Abt/Quadrupel  \
# Season country_user
# Autumn Andorra                     3.0            4.0             NaN
#        Antarctica                  NaN            NaN             NaN
#        Aotearoa                    NaN            NaN             NaN
#        Argentina                   1.0            NaN             NaN
#        Ascension Island            NaN            NaN             NaN
# ...                                ...            ...             ...
# Winter Uruguay                     3.0            1.0             NaN
#        Uzbekistan                  NaN            NaN             NaN
#        Venezuela                   4.0            5.0             5.0
#        Vietnam                     NaN            NaN             NaN
#        Wales                       1.0            4.0             2.0
#
# style                     Altbier   Amber Ale   Amber Lager/Vienna  \
# Season country_user
# ...

# %%
def sorting_styles(column):
    
    
    
    return sorted
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1334594/805639014.py in ?()
# ----> 1 seasonal_groups.sort_values(by = 'style', ascending=True)
#
# ~/miniconda3/envs/ada/lib/python3.9/site-packages/pandas/util/_decorators.py in ?(*args, **kwargs)
#     327                     msg.format(arguments=_format_argument_list(allow_args)),
#     328                     FutureWarning,
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#
# ~/miniconda3/envs/ada/lib/python3.9/site-packages/pandas/core/frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6908         elif len(by):
#    6909             # len(by) == 1
#    6910
#    6911             by = by[0]
# -> 6912             k = self._get_label_or_level_values(by, axis=axis)
#    6913
# ...
